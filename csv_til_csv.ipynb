# %%
import os
import glob
import pandas as pd
os.chdir("ferige_ssenorge/tg")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_tg.csv", index=False, encoding='utf-8-sig')

# %%
combined_csv.index = pd.to_datetime(combined_csv['time'],format="%Y-%m-%d")
combined_csv.sort_index()
# Out:
#                                     time    209.4.0   172.7.0   178.1.0  \
# time
# 1990-01-01 06:00:00  1990-01-01 06:00:00  -4.841616  1.372389  1.344750
# 1990-01-02 06:00:00  1990-01-02 06:00:00  -8.367072 -0.168389 -0.543875
# 1990-01-03 06:00:00  1990-01-03 06:00:00 -16.553251 -4.112389 -5.012125
# 1990-01-04 06:00:00  1990-01-04 06:00:00 -20.264479 -6.912500 -5.936812
# 1990-01-05 06:00:00  1990-01-05 06:00:00 -17.812817 -5.444944 -3.789813
# ...                                  ...        ...       ...       ...
# 2020-12-27 06:00:00  2020-12-27 06:00:00 -17.915422 -5.313612 -4.663063
# 2020-12-28 06:00:00  2020-12-28 06:00:00 -15.336276 -4.703945 -3.561688
# 2020-12-29 06:00:00  2020-12-29 06:00:00  -6.360135  2.765222  2.350062
# 2020-12-30 06:00:00  2020-12-30 06:00:00  -3.654871  1.353389  1.200687
# 2020-12-31 06:00:00  2020-12-31 06:00:00  -3.423826 -0.507389 -0.858062
#
#                       185.1.0    246.9.0    213.4.0    213.2.0    208.2.0  \
# time
# ...

# %%
df=pd.read_csv('combined_rr.csv', sep=(','))
df.sort_index()
# Out:
#                       time   209.4.0    172.7.0    178.1.0    185.1.0  \
# 0      2019-01-01 06:00:00  0.045586   3.950000  10.371250   4.827142
# 1      2019-01-02 06:00:00  6.140871   4.351667   9.873125   6.632857
# 2      2019-01-03 06:00:00  7.468289  13.082221  15.135625  10.304285
# 3      2019-01-04 06:00:00  2.447928  23.893890  29.532501  15.122857
# 4      2019-01-05 06:00:00  0.000000   0.000000   0.000000   0.517143
# ...                    ...       ...        ...        ...        ...
# 10952  2014-12-27 06:00:00  0.000000   4.749445   9.173750   0.961429
# 10953  2014-12-28 06:00:00  0.000150   0.026667   3.287500   0.107143
# 10954  2014-12-29 06:00:00  0.018258   0.000000   0.000000   4.237143
# 10955  2014-12-30 06:00:00  0.008348  11.111111  12.599375  10.297143
# 10956  2014-12-31 06:00:00  9.055105  19.852220  30.987500  16.067142
#
#         246.9.0    213.4.0    213.2.0    208.2.0    140.2.0  ...    26.20.0  \
# ...

# %%
combined_csv['2.290.0']
# Out:
# time
# 2019-01-01 06:00:00   NaN
# 2019-01-02 06:00:00   NaN
# 2019-01-03 06:00:00   NaN
# 2019-01-04 06:00:00   NaN
# 2019-01-05 06:00:00   NaN
#                        ..
# 2014-12-27 06:00:00   NaN
# 2014-12-28 06:00:00   NaN
# 2014-12-29 06:00:00   NaN
# 2014-12-30 06:00:00   NaN
# 2014-12-31 06:00:00   NaN
# Name: 2.290.0, Length: 10957, dtype: float64

# %%
df['83.12.0']

# %%
os.chdir("ferige_ssenorge/fsw_snow_amount/")

# %%
extension = 'csv'
first = 'combined_snow_depth'
all_filenames = [i for i in glob.glob('combined_snow_depth*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_snow_depth_final.csv", index=False, encoding='utf-8-sig')

# %%
combined_csv.index = pd.to_datetime(combined_csv['time'],format="%Y-%m-%d")
combined_csv.sort_index()
