# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import requests
import re

# %%
dirl  = "Final_dataset/"
files = os.listdir(dirl)
files=np.sort(files)
files_txt = [i for i in files if i.endswith('.txt_')]
files_txt = [i[:-5] for i in files if i.endswith('.txt_')]
files_txt.sort(key=int)
print(files_txt)
# Out:
# ['200013', '200032', '200142', '200268', '200279', '200284', '200290', '200303', '200323', '600010', '1200070', '1200171', '1200178', '1200193', '1500049', '1600066', '1600075', '1800010', '1800011', '1900079', '1900080', '1900082', '1900096', '1900104', '2000002', '2000011', '2200016', '2400008', '2400009', '2500024', '2600020', '2600021', '3600013', '4100001', '4100008', '4200002', '4800005', '5000001', '5000013', '5500004', '6200005', '6200010', '6200014', '6200015', '7500023', '7500028', '7600005', '7800008', '7900003', '8000004', '8100001', '8200004', '8300002', '8300006', '8300007', '8300012', '8400011', '8400020', '8500004', '8600010', '8600012', '8700010', '8800004', '8800011', '9100002', '9700001', '9800004', '10100001', '10400022', '10400023', '10500001', '10900009', '11200008', '12200011', '12300031', '12400002', '12700006', '12700011', '12700013', '12800005', '13300007', '13800001', '13900020', '13900026', '13900035', '14000002', '14800002', '15100015', '15200004', '15300001', '15600008', '15600010', '15600015', '16300007', '16800003', '17200007', '17200008', '17700004', '17800001', '18500001', '19100002', '19600007', '19600011', '20000004', '20500006', '20600003', '20800002', '20800003', '20900004', '21200010', '21200049', '21300002', '21300004', '22300002', '23400018', '24400002', '24600009', '24700003', '30700005', '30700007', '30800001', '31100004', '31100460', '31300010']

# %%
new_list = []
for i in files_txt:
    new_list.append(i[0:-5]+'.'+i[-5:])
re_zero = r"[0]{2,4}"
removed_zeros = []
for i in new_list:
    j = i+".0"
    removed_zeros.append(re.sub(re_zero, "", j))
print(
    removed_zeros
)
ny_my_st = removed_zeros
# Out:
# ['2.13.0', '2.32.0', '2.142.0', '2.268.0', '2.279.0', '2.284.0', '2.290.0', '2.303.0', '2.323.0', '6.10.0', '12.70.0', '12.171.0', '12.178.0', '12.193.0', '15.49.0', '16.66.0', '16.75.0', '18.10.0', '18.11.0', '19.79.0', '19.80.0', '19.82.0', '19.96.0', '19.104.0', '20.2.0', '20.11.0', '22.16.0', '24.8.0', '24.9.0', '25.24.0', '26.20.0', '26.21.0', '36.13.0', '41.1.0', '41.8.0', '42.2.0', '48.5.0', '50.1.0', '50.13.0', '55.4.0', '62.5.0', '62.10.0', '62.14.0', '62.15.0', '75.23.0', '75.28.0', '76.5.0', '78.8.0', '79.3.0', '80.4.0', '81.1.0', '82.4.0', '83.2.0', '83.6.0', '83.7.0', '83.12.0', '84.11.0', '84.20.0', '85.4.0', '86.10.0', '86.12.0', '87.10.0', '88.4.0', '88.11.0', '91.2.0', '97.1.0', '98.4.0', '101.1.0', '104.22.0', '104.23.0', '105.1.0', '109.9.0', '112.8.0', '122.11.0', '123.31.0', '124.2.0', '127.6.0', '127.11.0', '127.13.0', '128.5.0', '133.7.0', '138.1.0', '139.20.0', '139.26.0', '139.35.0', '140.2.0', '148.2.0', '151.15.0', '152.4.0', '153.1.0', '156.8.0', '156.10.0', '156.15.0', '163.7.0', '168.3.0', '172.7.0', '172.8.0', '177.4.0', '178.1.0', '185.1.0', '191.2.0', '196.7.0', '196.11.0', '2.4.0', '205.6.0', '206.3.0', '208.2.0', '208.3.0', '209.4.0', '212.10.0', '212.49.0', '213.2.0', '213.4.0', '223.2.0', '234.18.0', '244.2.0', '246.9.0', '247.3.0', '307.5.0', '307.7.0', '308.1.0', '311.4.0', '311.460.0', '313.10.0']

# %%
ny_my_st.remove('2.4.0')
ny_my_st.remove('50.13.0')
print(ny_my_st[1:])
len(ny_my_st)
# Out:
# ['2.32.0', '2.142.0', '2.268.0', '2.279.0', '2.284.0', '2.290.0', '2.303.0', '2.323.0', '6.10.0', '12.70.0', '12.171.0', '12.178.0', '12.193.0', '15.49.0', '16.66.0', '16.75.0', '18.10.0', '18.11.0', '19.79.0', '19.80.0', '19.82.0', '19.96.0', '19.104.0', '20.2.0', '20.11.0', '22.16.0', '24.8.0', '24.9.0', '25.24.0', '26.20.0', '26.21.0', '36.13.0', '41.1.0', '41.8.0', '42.2.0', '48.5.0', '50.1.0', '55.4.0', '62.5.0', '62.10.0', '62.14.0', '62.15.0', '75.23.0', '75.28.0', '76.5.0', '78.8.0', '79.3.0', '80.4.0', '81.1.0', '82.4.0', '83.2.0', '83.6.0', '83.7.0', '83.12.0', '84.11.0', '84.20.0', '85.4.0', '86.10.0', '86.12.0', '87.10.0', '88.4.0', '88.11.0', '91.2.0', '97.1.0', '98.4.0', '101.1.0', '104.22.0', '104.23.0', '105.1.0', '109.9.0', '112.8.0', '122.11.0', '123.31.0', '124.2.0', '127.6.0', '127.11.0', '127.13.0', '128.5.0', '133.7.0', '138.1.0', '139.20.0', '139.26.0', '139.35.0', '140.2.0', '148.2.0', '151.15.0', '152.4.0', '153.1.0', '156.8.0', '156.10.0', '156.15.0', '163.7.0', '168.3.0', '172.7.0', '172.8.0', '177.4.0', '178.1.0', '185.1.0', '191.2.0', '196.7.0', '196.11.0', '205.6.0', '206.3.0', '208.2.0', '208.3.0', '209.4.0', '212.10.0', '212.49.0', '213.2.0', '213.4.0', '223.2.0', '234.18.0', '244.2.0', '246.9.0', '247.3.0', '307.5.0', '307.7.0', '308.1.0', '311.4.0', '311.460.0', '313.10.0']
# 122

# %%
url = "https://hydapi.nve.no/api/v1/Stations?StationId="+'2.13.0'+"&Active=0"
head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
r = requests.get(url = url, headers=head)
r_res = r.json()
r_data = r_res['data']
    
for i in r_data:
    df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
    'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
    'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
    'length_km_basin': i['lengthKmBasin']}

# %%
url = "https://hydapi.nve.no/api/v1/Stations?StationId="+ny_my_st[60]+"&Active=0"
head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
r = requests.get(url = url, headers=head)
r_res = r.json()
r_data = r_res['data']
    
for i in r_data:
    df2 = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
    'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
    'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
    'length_km_basin': i['lengthKmBasin']}

# %%
m = pd.DataFrame()
m=m.append(df, ignore_index=True)
m
# Out:
#    Areal  Breiddegrad  Lengdegrad   St_nr       Stasjonsnamn  height_maximum  \
# 0  480.7     61.56064     8.91856  2.13.0  Nedre Sjodalsvatn          2363.0
#
#    height_minimum  length_km_basin  maslStation  perc_agricul  perc_bog  \
# 0           940.0            36.97        942.0           0.0      0.83
#
#    perc_eff_lake  perc_forest  perc_glacier  perc_lake  perc_mountain  \
# 0           4.19         5.41          8.32       9.15          71.77
#
#    perc_urban
# 0         0.0

# %%
for nr in ny_my_st[1:10]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[10:20]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[20:30]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[30:40]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[40:50]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[50:60]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
s = pd.DataFrame()
s=s.append(df2, ignore_index=True)
s
# Out:
#    Areal  Breiddegrad  Lengdegrad    St_nr           Stasjonsnamn  \
# 0  218.6      61.7186     6.52064  87.10.0  Gloppenelv v/Bergheim
#
#    height_maximum  height_minimum  length_km_basin  maslStation  perc_agricul  \
# 0          1823.0           138.0            23.88        140.0          3.06
#
#    perc_bog  perc_eff_lake  perc_forest  perc_glacier  perc_lake  \
# 0      0.34           0.26        17.54         16.54       1.22
#
#    perc_mountain  perc_urban
# 0          52.92         0.0

# %%
for nr in ny_my_st[60:70]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[70:80]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[80:90]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[90:100]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[100:110]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
for nr in ny_my_st[110:124]:
    url = "https://hydapi.nve.no/api/v1/Stations?StationId="+nr+"&Active=0"
    head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
    r = requests.get(url = url, headers=head)
    r_res = r.json()
    r_data = r_res['data']
    for i in r_data:
        df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
        'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
        'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
        'length_km_basin': i['lengthKmBasin']}
    m=m.append(df, ignore_index=True)

# %%
url = "https://hydapi.nve.no/api/v1/Stations?StationId="+'200.4.0'+"&Active=0"
head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
r = requests.get(url = url, headers=head)
r_res = r.json()
r_res
r_data = r_res['data']
for i in r_data:
    df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
    'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
    'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
    'length_km_basin': i['lengthKmBasin']}

m=m.append(df, ignore_index=True)

# %%
m
# Out:
#        Areal  Breiddegrad  Lengdegrad      St_nr             Stasjonsnamn  \
# 0     480.70     61.56064     8.91856     2.13.0        Nedre Sjodalsvatn
# 1     463.30     61.85194    10.22212     2.32.0                  Atnasjø
# 2    1643.02     60.64117    12.04712    2.142.0                  Knappom
# 3     789.27     61.79955     8.44722    2.268.0                   Akslen
# 4     435.21     60.13345    11.08010    2.279.0                 Kråkfoss
# ..       ...          ...         ...        ...                      ...
# 118   449.98     64.24487    13.76031    308.1.0               Lenglingen
# 119  1794.03     61.91996    11.94004    311.4.0  Femundsenden (Femunden)
# 120   394.83     61.66524    12.01897  311.460.0                  Engeren
# 121   357.86     59.95464    12.18729   313.10.0                   Magnor
# 122   136.01     69.98093    19.10412    200.4.0           Skogsfjordvatn
#
#      height_maximum  height_minimum  length_km_basin  maslStation  \
# 0            2363.0           940.0            36.97        942.0
# 1            2170.0           701.0            34.05        701.0
# 2             807.0           170.0            65.17        177.0
# 3            2462.0           476.0            35.94        476.0
# 4             807.0           105.0            40.75        122.0
# ..              ...             ...              ...          ...
# 118          1387.0           354.0            28.52        354.0
# 119          1455.0           652.0            68.87        663.0
# 120          1207.0           472.0            26.19        479.0
# 121           458.0           127.0           146.87        136.0
# 122          1047.0            19.0            17.28         20.0
#
#      perc_agricul  perc_bog  perc_eff_lake  perc_forest  perc_glacier  \
# 0            0.00      0.83           4.19         5.41          8.32
# 1            0.43      2.16           1.08        22.23          0.00
# 2            2.19     15.89           0.09        72.73          0.00
# 3            0.63      0.38           0.06        11.40         10.90
# 4           11.03      4.14           0.42        75.60          0.00
# ..            ...       ...            ...          ...           ...
# 118          0.52     21.54           4.13        39.77          0.00
# 119          0.39      7.48          11.81        32.44          0.00
# 120          1.00     13.08           2.99        50.56          0.00
# 121          7.54      5.03           0.34        81.04          0.00
# 122          0.42      1.29          10.12        21.25          0.00
#
#      perc_lake  perc_mountain  perc_urban
# 0         9.15          71.77        0.00
# 1         1.73          68.21        0.00
# 2         1.83           0.00        0.00
# 3         1.90          71.21        0.00
# 4         3.91           0.00        3.22
# ..         ...            ...         ...
# 118       8.07          24.81        0.03
# 119      18.42          27.08        0.00
# 120       3.98          28.85        0.04
# 121       3.91           0.00        0.28
# 122      14.80          49.73        0.00
#
# [123 rows x 17 columns]

# %%
m.index=m['St_nr']

m
# Out:
#              Areal  Breiddegrad  Lengdegrad      St_nr  \
# St_nr
# 2.13.0      480.70     61.56064     8.91856     2.13.0
# 2.32.0      463.30     61.85194    10.22212     2.32.0
# 2.142.0    1643.02     60.64117    12.04712    2.142.0
# 2.268.0     789.27     61.79955     8.44722    2.268.0
# 2.279.0     435.21     60.13345    11.08010    2.279.0
# ...            ...          ...         ...        ...
# 308.1.0     449.98     64.24487    13.76031    308.1.0
# 311.4.0    1794.03     61.91996    11.94004    311.4.0
# 311.460.0   394.83     61.66524    12.01897  311.460.0
# 313.10.0    357.86     59.95464    12.18729   313.10.0
# 200.4.0     136.01     69.98093    19.10412    200.4.0
#
#                       Stasjonsnamn  height_maximum  height_minimum  \
# St_nr
# 2.13.0           Nedre Sjodalsvatn          2363.0           940.0
# 2.32.0                     Atnasjø          2170.0           701.0
# 2.142.0                    Knappom           807.0           170.0
# 2.268.0                     Akslen          2462.0           476.0
# 2.279.0                   Kråkfoss           807.0           105.0
# ...                            ...             ...             ...
# 308.1.0                 Lenglingen          1387.0           354.0
# 311.4.0    Femundsenden (Femunden)          1455.0           652.0
# 311.460.0                  Engeren          1207.0           472.0
# 313.10.0                    Magnor           458.0           127.0
# 200.4.0             Skogsfjordvatn          1047.0            19.0
#
#            length_km_basin  maslStation  perc_agricul  perc_bog  \
# St_nr
# 2.13.0               36.97        942.0          0.00      0.83
# 2.32.0               34.05        701.0          0.43      2.16
# 2.142.0              65.17        177.0          2.19     15.89
# 2.268.0              35.94        476.0          0.63      0.38
# 2.279.0              40.75        122.0         11.03      4.14
# ...                    ...          ...           ...       ...
# 308.1.0              28.52        354.0          0.52     21.54
# 311.4.0              68.87        663.0          0.39      7.48
# 311.460.0            26.19        479.0          1.00     13.08
# 313.10.0            146.87        136.0          7.54      5.03
# 200.4.0              17.28         20.0          0.42      1.29
#
#            perc_eff_lake  perc_forest  perc_glacier  perc_lake  perc_mountain  \
# St_nr
# 2.13.0              4.19         5.41          8.32       9.15          71.77
# 2.32.0              1.08        22.23          0.00       1.73          68.21
# 2.142.0             0.09        72.73          0.00       1.83           0.00
# 2.268.0             0.06        11.40         10.90       1.90          71.21
# 2.279.0             0.42        75.60          0.00       3.91           0.00
# ...                  ...          ...           ...        ...            ...
# 308.1.0             4.13        39.77          0.00       8.07          24.81
# 311.4.0            11.81        32.44          0.00      18.42          27.08
# 311.460.0           2.99        50.56          0.00       3.98          28.85
# 313.10.0            0.34        81.04          0.00       3.91           0.00
# 200.4.0            10.12        21.25          0.00      14.80          49.73
#
#            perc_urban
# St_nr
# 2.13.0           0.00
# 2.32.0           0.00
# 2.142.0          0.00
# 2.268.0          0.00
# 2.279.0          3.22
# ...               ...
# 308.1.0          0.03
# 311.4.0          0.00
# 311.460.0        0.04
# 313.10.0         0.28
# 200.4.0          0.00
#
# [123 rows x 17 columns]

# %%
m = m[~m.index.duplicated(keep='first')]
m.sort_index
m
# Out:
#              Areal  Breiddegrad  Lengdegrad      St_nr  \
# St_nr
# 2.13.0      480.70     61.56064     8.91856     2.13.0
# 2.32.0      463.30     61.85194    10.22212     2.32.0
# 2.142.0    1643.02     60.64117    12.04712    2.142.0
# 2.268.0     789.27     61.79955     8.44722    2.268.0
# 2.279.0     435.21     60.13345    11.08010    2.279.0
# ...            ...          ...         ...        ...
# 308.1.0     449.98     64.24487    13.76031    308.1.0
# 311.4.0    1794.03     61.91996    11.94004    311.4.0
# 311.460.0   394.83     61.66524    12.01897  311.460.0
# 313.10.0    357.86     59.95464    12.18729   313.10.0
# 200.4.0     136.01     69.98093    19.10412    200.4.0
#
#                       Stasjonsnamn  height_maximum  height_minimum  \
# St_nr
# 2.13.0           Nedre Sjodalsvatn          2363.0           940.0
# 2.32.0                     Atnasjø          2170.0           701.0
# 2.142.0                    Knappom           807.0           170.0
# 2.268.0                     Akslen          2462.0           476.0
# 2.279.0                   Kråkfoss           807.0           105.0
# ...                            ...             ...             ...
# 308.1.0                 Lenglingen          1387.0           354.0
# 311.4.0    Femundsenden (Femunden)          1455.0           652.0
# 311.460.0                  Engeren          1207.0           472.0
# 313.10.0                    Magnor           458.0           127.0
# 200.4.0             Skogsfjordvatn          1047.0            19.0
#
#            length_km_basin  maslStation  perc_agricul  perc_bog  \
# St_nr
# 2.13.0               36.97        942.0          0.00      0.83
# 2.32.0               34.05        701.0          0.43      2.16
# 2.142.0              65.17        177.0          2.19     15.89
# 2.268.0              35.94        476.0          0.63      0.38
# 2.279.0              40.75        122.0         11.03      4.14
# ...                    ...          ...           ...       ...
# 308.1.0              28.52        354.0          0.52     21.54
# 311.4.0              68.87        663.0          0.39      7.48
# 311.460.0            26.19        479.0          1.00     13.08
# 313.10.0            146.87        136.0          7.54      5.03
# 200.4.0              17.28         20.0          0.42      1.29
#
#            perc_eff_lake  perc_forest  perc_glacier  perc_lake  perc_mountain  \
# St_nr
# 2.13.0              4.19         5.41          8.32       9.15          71.77
# 2.32.0              1.08        22.23          0.00       1.73          68.21
# 2.142.0             0.09        72.73          0.00       1.83           0.00
# 2.268.0             0.06        11.40         10.90       1.90          71.21
# 2.279.0             0.42        75.60          0.00       3.91           0.00
# ...                  ...          ...           ...        ...            ...
# 308.1.0             4.13        39.77          0.00       8.07          24.81
# 311.4.0            11.81        32.44          0.00      18.42          27.08
# 311.460.0           2.99        50.56          0.00       3.98          28.85
# 313.10.0            0.34        81.04          0.00       3.91           0.00
# 200.4.0            10.12        21.25          0.00      14.80          49.73
#
#            perc_urban
# St_nr
# 2.13.0           0.00
# 2.32.0           0.00
# 2.142.0          0.00
# 2.268.0          0.00
# 2.279.0          3.22
# ...               ...
# 308.1.0          0.03
# 311.4.0          0.00
# 311.460.0        0.04
# 313.10.0         0.28
# 200.4.0          0.00
#
# [123 rows x 17 columns]

# %%
m.to_excel('Nye_stasjonar5.xlsx')

# %%
m
# Out:
#              Areal  Breiddegrad  Lengdegrad      St_nr  \
# St_nr
# 2.13.0      480.70     61.56064     8.91856     2.13.0
# 2.32.0      463.30     61.85194    10.22212     2.32.0
# 2.142.0    1643.02     60.64117    12.04712    2.142.0
# 2.268.0     789.27     61.79955     8.44722    2.268.0
# 2.279.0     435.21     60.13345    11.08010    2.279.0
# ...            ...          ...         ...        ...
# 308.1.0     449.98     64.24487    13.76031    308.1.0
# 311.4.0    1794.03     61.91996    11.94004    311.4.0
# 311.460.0   394.83     61.66524    12.01897  311.460.0
# 313.10.0    357.86     59.95464    12.18729   313.10.0
# 200.4.0     136.01     69.98093    19.10412    200.4.0
#
#                       Stasjonsnamn  height_maximum  height_minimum  \
# St_nr
# 2.13.0           Nedre Sjodalsvatn          2363.0           940.0
# 2.32.0                     Atnasjø          2170.0           701.0
# 2.142.0                    Knappom           807.0           170.0
# 2.268.0                     Akslen          2462.0           476.0
# 2.279.0                   Kråkfoss           807.0           105.0
# ...                            ...             ...             ...
# 308.1.0                 Lenglingen          1387.0           354.0
# 311.4.0    Femundsenden (Femunden)          1455.0           652.0
# 311.460.0                  Engeren          1207.0           472.0
# 313.10.0                    Magnor           458.0           127.0
# 200.4.0             Skogsfjordvatn          1047.0            19.0
#
#            length_km_basin  maslStation  perc_agricul  perc_bog  \
# St_nr
# 2.13.0               36.97        942.0          0.00      0.83
# 2.32.0               34.05        701.0          0.43      2.16
# 2.142.0              65.17        177.0          2.19     15.89
# 2.268.0              35.94        476.0          0.63      0.38
# 2.279.0              40.75        122.0         11.03      4.14
# ...                    ...          ...           ...       ...
# 308.1.0              28.52        354.0          0.52     21.54
# 311.4.0              68.87        663.0          0.39      7.48
# 311.460.0            26.19        479.0          1.00     13.08
# 313.10.0            146.87        136.0          7.54      5.03
# 200.4.0              17.28         20.0          0.42      1.29
#
#            perc_eff_lake  perc_forest  perc_glacier  perc_lake  perc_mountain  \
# St_nr
# 2.13.0              4.19         5.41          8.32       9.15          71.77
# 2.32.0              1.08        22.23          0.00       1.73          68.21
# 2.142.0             0.09        72.73          0.00       1.83           0.00
# 2.268.0             0.06        11.40         10.90       1.90          71.21
# 2.279.0             0.42        75.60          0.00       3.91           0.00
# ...                  ...          ...           ...        ...            ...
# 308.1.0             4.13        39.77          0.00       8.07          24.81
# 311.4.0            11.81        32.44          0.00      18.42          27.08
# 311.460.0           2.99        50.56          0.00       3.98          28.85
# 313.10.0            0.34        81.04          0.00       3.91           0.00
# 200.4.0            10.12        21.25          0.00      14.80          49.73
#
#            perc_urban
# St_nr
# 2.13.0           0.00
# 2.32.0           0.00
# 2.142.0          0.00
# 2.268.0          0.00
# 2.279.0          3.22
# ...               ...
# 308.1.0          0.03
# 311.4.0          0.00
# 311.460.0        0.04
# 313.10.0         0.28
# 200.4.0          0.00
#
# [123 rows x 17 columns]

# %%
url = "https://hydapi.nve.no/api/v1/Stations?StationId="+ny_my_st[121]+"&Active=0"
head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
r = requests.get(url = url, headers=head)
r_res = r.json()
r_res
r_data = r_res['data']
for i in r_data:
    df = {"St_nr":i['stationId'], 'Stasjonsnamn': i['stationName'], 'Areal': i['drainageBasinArea'], 'Breiddegrad': i['latitude'], 'Lengdegrad': i['longitude'], 'maslStation': i['masl'],
    'perc_agricul': i['percentAgricul'], 'perc_bog': i['percentBog'], 'perc_eff_lake': i['percentEffLake'], 'perc_forest': i['percentForest'], 'perc_glacier': i['percentGlacier'], 
    'perc_lake': i['percentLake'], 'perc_mountain': i['percentMountain'], 'perc_urban': i['percentUrban'], 'height_minimum': i['heightMinimum'], 'height_maximum': i['heightMaximum'], 
    'length_km_basin': i['lengthKmBasin']}

# %%
url = "https://hydapi.nve.no/api/v1/Stations?StationId="+ny_my_st[60]+"&Active=0"
head = {"Accept": "application/json",  "X-API-Key": "rjaZ9eZu70y6Cwe3/93DRA=="}
r = requests.get(url = url, headers=head)
r_res = r.json()
r_res
# Out:
# {'currentLink': 'https://hydapi.nve.no/api/v1/Stations?StationId=87.10.0&Active=0',
#  'apiVersion': '1.0',
#  'license': 'https://data.norge.no/nlod/en',
#  'createdAt': '2022-03-09T10:51:26.4098872Z',
#  'queryTime': '00:00:00.0022257',
#  'itemCount': 1,
#  'data': [{'stationId': '87.10.0',
#    'stationName': 'Gloppenelv v/Bergheim',
#    'latitude': 61.7186,
#    'longitude': 6.52064,
#    'utmEast_Z33': 52688,
#    'utmNorth_Z33': 6872059,
#    'masl': 140,
#    'riverName': 'Breimsvassdraget',
#    'councilNumber': '4650',
#    'councilName': 'Gloppen',
#    'countyName': 'Vestland',
#    'drainageBasinKey': 2280,
#    'hierarchy': 'Breimsvassdraget',
#    'lakeArea': 0,
#    'lakeName': '',
#    'lakeNo': 0,
#    'regineNo': '087.D22',
#    'reservoirNo': '',
#    'reservoirName': '',
#    'stationTypeName': 'Privat, pålagt',
#    'stationStatusName': 'Aktiv',
#    'drainageBasinArea': 218.6,
#    'drainageBasinAreaNorway': 218.6,
#    'gradient1085': 6.35,
#    'gradientBasin': None,
#    'gradientRiver': 40.18,
#    'heightMinimum': 138,
#    'heightHypso10': 331,
#    'heightHypso20': 568,
#    'heightHypso30': 757,
#    'heightHypso40': 906,
#    'heightHypso50': 1045,
#    'heightHypso60': 1157,
#    'heightHypso70': 1274,
#    'heightHypso80': 1405,
#    'heightHypso90': 1558,
#    'heightMaximum': 1823,
#    'lengthKmBasin': 23.88,
#    'lengthKmRiver': 32.11,
#    'percentAgricul': 3.06,
#    'percentBog': 0.34,
#    'percentEffBog': None,
#    'percentEffLake': 0.26,
#    'percentForest': 17.54,
#    'percentGlacier': 16.54,
#    'percentLake': 1.22,
#    'percentMountain': 52.92,
#    'percentUrban': 0,
#    'utmZoneGravi': None,
#    'utmEastGravi': None,
#    'utmNorthGravi': None,
#    'utmZoneInlet': None,
#    'utmEastInlet': None,
#    'utmNorthInlet': None,
#    'utmZoneOutlet': None,
#    'utmEastOutlet': None,
#    'utmNorthOutlet': None,
#    'annualRunoff': 537.78,
#    'specificDischarge': 77.96,
#    'regulationArea': 0,
#    'areaReservoirs': 0,
#    'volumeReservoirs': 0,
#    'regulationPartReservoirs': 0,
#    'transferAreaIn': 203.7,
#    'transferAreaOut': 0,
#    'reservoirAreaIn': 0,
#    'reservoirAreaOut': 0,
#    'reservoirVolumeIn': 0,
#    'reservoirVolumeOut': 0,
#    'remainingArea': 0,
#    'numberReservoirs': 0,
#    'firstYearRegulation': 2001,
#    'catchmentRegTypeName': 'Uregulert',
#    'owner': 'GLOPPEN ENERGI AS',
#    'qNumberOfYears': 32,
#    'qStartYear': 1986,
#    'qEndYear': 2017,
#    'qm': 110.1119,
#    'q5': 130.92,
#    'q10': 148.7822,
#    'q20': 166.3113,
#    'q50': 189.5902,
#    'hm': 2.3377,
#    'h5': 2.5444,
#    'h10': 2.7132,
#    'h20': 2.8724,
#    'h50': 3.0753,
#    'culQm': 162.6423,
#    'culQ5': 208.0512,
#    'culQ10': 241.1298,
#    'culQ20': 272.3348,
#    'culQ50': 310.4539,
#    'culHm': 2.8396,
#    'culH5': 3.2304,
#    'culH10': 3.4972,
#    'culH20': 3.7378,
#    'culH50': 4.0196,
#    'seriesList': [{'parameterName': 'Vannstand',
#      'parameter': 1000,
#      'versionNo': 1,
#      'unit': 'm',
#      'serieFrom': '2006-11-14T00:00:00',
#      'serieTo': None,
#      'resolutionList': [{'resTime': 0,
#        'method': 'Instantaneous',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-14T09:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 60,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-14T10:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 1440,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-14T11:00:00Z',
#        'dataToTime': '2022-03-08T11:00:00Z'}]},
#     {'parameterName': 'Vannføring',
#      'parameter': 1001,
#      'versionNo': 1,
#      'unit': 'm³/s',
#      'serieFrom': None,
#      'serieTo': None,
#      'resolutionList': [{'resTime': 0,
#        'method': 'Instantaneous',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-14T09:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 60,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-14T09:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 1440,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2006-11-15T11:00:00Z',
#        'dataToTime': '2022-03-08T11:00:00Z'}]},
#     {'parameterName': 'Lufttemperatur',
#      'parameter': 17,
#      'versionNo': 1,
#      'unit': '°C',
#      'serieFrom': '2009-02-11T00:00:00',
#      'serieTo': None,
#      'resolutionList': [{'resTime': 0,
#        'method': 'Instantaneous',
#        'timeOffset': 0,
#        'dataFromTime': '2009-02-16T11:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 60,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2009-02-16T12:00:00Z',
#        'dataToTime': '2022-03-09T10:00:00Z'},
#       {'resTime': 1440,
#        'method': 'Mean',
#        'timeOffset': 0,
#        'dataFromTime': '2009-02-17T11:00:00Z',
#        'dataToTime': '2022-03-08T11:00:00Z'}]}]}]}
